# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('../a1images/shells.jpg', cv.IMREAD_GRAYSCALE)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

hist, bins = np.histogram(img.ravel(), 256, [0, 256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()
axes[0].hist(img.flatten(), 256, [0, 256], color='r')
axes[0].set_xlim([0, 256])
axes[0].set_title('Histogram of the Original Image')

equ = cv.equalizeHist(img)
hist, bins = np.histogram(equ.ravel(), 256, [0, 256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()
axes[1].hist(equ.flatten(), 256, [0, 256], color='b')
axes[1].set_xlim([0, 256])
axes[1].set_title('Histogram of the Equalized Image')

res = np.hstack((img, equ))
axes[2].imshow(res, cmap='gray')
axes[2].axis('off')

plt.tight_layout()
plt.show()
